# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_html('SaleMonDetail.html', encoding='utf-8')

# %%
arr = df[0]
type(arr)
# Out:
# pandas.core.frame.DataFrame

# %%
data = np.array(arr[806:807])
d = data.tolist()
d[0]
# Out:
# ['市場',
#  '代碼',
#  '股票名稱',
#  '股東會日期',
#  '除息日程',
#  '除息日程',
#  '除息日程',
#  '除息日程',
#  '除息日程',
#  '除權日程',
#  '除權日程',
#  '除權日程',
#  '除權日程',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)',
#  '股東股利\xa0(元/股)']

# %%
arr.columns = d[0]
arr
# Out:
#      市場      代碼      股票名稱     股東會日期      除息日程   除息日程      除息日程    除息日程  \
# 0    上市    0050    元大台灣50       NaN  20'07/21  96.35  20'07/21       1
# 1    上市    0050    元大台灣50       NaN  20'01/31  89.25  20'02/06       5
# 2    上市    0052      富邦科技       NaN  20'04/22  63.05  20'04/22       1
# 3    上市  006203  元大MSCI台灣       NaN  20'07/21  45.42  20'07/21       1
# 4    上市  006203  元大MSCI台灣       NaN  20'01/31   42.1  20'02/13      10
# ..   ..     ...       ...       ...       ...    ...       ...     ...
# 804  上市    9945       潤泰新  20'06/09  20'07/16   52.8  20'08/06      16
# 805  上市    9958       世紀鋼  20'06/17  20'08/20  104.5  20'08/24       3
# 806  市場      代碼      股票名稱     股東會日期      除息日程   除息日程      除息日程    除息日程
# 807  市場      代碼      股票名稱     股東會日期     除息交易日  除息參考價    填息完成日期  填息花費日數
# 808  市場      代碼      股票名稱     股東會日期     除息交易日  除息參考價    填息完成日期  填息花費日數
#
#          除息日程      除權日程   除權日程    除權日程    除權日程  股東股利 (元/股)  股東股利 (元/股)  \
# 0         NaN       NaN    NaN     NaN     NaN         0.7           0
# 1         NaN       NaN    NaN     NaN     NaN         2.9           0
# 2         NaN       NaN    NaN     NaN     NaN        1.93           0
# 3         NaN       NaN    NaN     NaN     NaN        0.28           0
# 4         NaN       NaN    NaN     NaN     NaN         1.4           0
# ..        ...       ...    ...     ...     ...         ...         ...
# 804  20'08/17  20'08/19  36.45     NaN     NaN           1           0
# 805  20'09/18       NaN    NaN     NaN     NaN        0.99           0
# 806      除息日程      除權日程   除權日程    除權日程    除權日程  股東股利 (元/股)  股東股利 (元/股)
# 807   現金股利發放日     除權交易日  除權參考價  填權完成日期  填權花費日數        現金股利        現金股利
# 808   現金股利發放日     除權交易日  除權參考價  填權完成日期  填權花費日數          盈餘          公積
#
#      股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)
# 0           0.7           0           0           0         0.7
# 1           2.9           0           0           0         2.9
# 2          1.93           0           0           0        1.93
# 3          0.28           0           0           0        0.28
# 4           1.4           0           0           0         1.4
# ..          ...         ...         ...         ...         ...
# 804           1           5           0           5           6
# 805        0.99           0           0           0        0.99
# 806  股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)  股東股利 (元/股)
# 807        現金股利        股票股利        股票股利        股票股利        股利合計
# 808          合計          盈餘          公積          合計        股利合計
#
# [809 rows x 20 columns]

# %%
df = arr[['代碼', '股票名稱', '股東會日期','除息日程']]
df = df.iloc[:,:4]
df
# Out:
#          代碼      股票名稱     股東會日期      除息日程
# 0      0050    元大台灣50       NaN  20'07/21
# 1      0050    元大台灣50       NaN  20'01/31
# 2      0052      富邦科技       NaN  20'04/22
# 3    006203  元大MSCI台灣       NaN  20'07/21
# 4    006203  元大MSCI台灣       NaN  20'01/31
# ..      ...       ...       ...       ...
# 804    9945       潤泰新  20'06/09  20'07/16
# 805    9958       世紀鋼  20'06/17  20'08/20
# 806      代碼      股票名稱     股東會日期      除息日程
# 807      代碼      股票名稱     股東會日期     除息交易日
# 808      代碼      股票名稱     股東會日期     除息交易日
#
# [809 rows x 4 columns]

# %%
stock_id_list = ['2412','3045','2105','1229','9290']

key0 = '代碼'
key1 = '股票名稱'
key2 = '股東會日期'
key3 = '除息日程'

for i in range(0, len(stock_id_list)):
    stock_df = df[df[key0] == stock_id_list[i]]
    
    try:
        if stock_df[[key0]].values[0] == stock_id_list[i]:
            print(" {} - {} - {}".format(stock_df[[key1]].values[0],stock_df[[key2]].values[0],stock_df[[key3]].values[0]))
    except:
        print("No ",stock_id_list[i])
# Out:
#  ['中華電'] - ["20'05/29"] - ["20'07/02"]
#  ['台灣大'] - ["20'06/18"] - ["20'07/17"]
#  ['正新'] - ["20'06/16"] - ["20'07/23"]
#  ['聯華'] - ["20'06/23"] - ["20'08/12"]
# No  9290
